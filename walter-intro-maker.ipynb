# %%
from langchain_aws import ChatBedrock
import os

claude_3_7_bedrock = ChatBedrock(
    model_id="arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    provider="anthropic",
    model_kwargs={"max_tokens": 20000,
    # "thinking": {"type": "enabled", "budget_tokens": 1024}
    },
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
)

claude_3_7_bedrock_thinking = ChatBedrock(
    model_id="arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    provider="anthropic",
    model_kwargs={"max_tokens": 20000,
    "thinking": {"type": "enabled", "budget_tokens": 1024}
    },
)

# %%
claude_3_7_bedrock.invoke("Hello, how are you?")
# Out:
# AIMessage(content="I'm doing well, thank you for asking! I'm here and ready to help with any questions or topics you'd like to discuss. How are you today?", additional_kwargs={'usage': {'prompt_tokens': 13, 'completion_tokens': 36, 'total_tokens': 49}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0'}, response_metadata={'usage': {'prompt_tokens': 13, 'completion_tokens': 36, 'total_tokens': 49}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0'}, id='run-bc229901-ff4c-4194-9ade-fa6248bef79f-0', usage_metadata={'input_tokens': 13, 'output_tokens': 36, 'total_tokens': 49})

# %%
from langgraph.graph import END, StateGraph
from typing import Literal, TypedDict, List
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# ## GSheets

# %%
# login using service account
from google.oauth2 import service_account
import pandas as pd
import gspread
from gspread_pandas import Spread

# Configurar credenciais
credentials = service_account.Credentials.from_service_account_file(
    ".secrets/service-account-admin.json",
    scopes=['https://www.googleapis.com/auth/spreadsheets', 
            'https://www.googleapis.com/auth/drive']
)

# Conectar ao Google Sheets
gc = gspread.authorize(credentials)

# Extrair o ID da planilha da URL
sheet_id = "11I9QFSMFn7UBfV0wz0-hAYgWtIKytTVnWA9pjquwgdk"

# Abrir a planilha e obter a primeira aba
sheet = gc.open_by_key(sheet_id).sheet1

# Obter todos os dados e converter para DataFrame
data = sheet.get_all_values()
headers = data[0]
df = pd.DataFrame(data[1:], columns=headers)

# Exibir as primeiras linhas do DataFrame
df.head(3)
# Out:
#                   name proximity industry_agnostic              leader?  \
# 0         Bridge Latam         3              TRUE        Pure-follower
# 1              Latitud         3              TRUE        Pure-follower
# 2  Andreessen Horowitz         3              TRUE  Leader and Follower
#
#   investment_geography preferred_industry vc_quality_perception  \
# 0                Latam                 []                   3.0
# 1                Latam                 []                   4.0
# 2               Global                 []                   5.0
#
#                                         observations  \
# 0                  Agnostic, low bar for investments
# 1  Top-tier pre-seed dealflow. Have an active acc...
# 2                         Focusing more on Series A+
#
#                                    investment_range       geo_origin  ...    \
# 0                                       [< USD 1mn]  Latam ex-Brazil  ...
# 1                            [< USD 1mn, USD 1-5mn]           Brazil  ...
# 2  [USD 1-5mn, USD 5-10mn, USD 10-20mn, > USD 20mn]    Outside Latam  ...
#
#   Opiniao Cache investor_profile  \
# 0                             VC
# 1                             VC
# 2                             VC
#
#                           prefered_industry_enriched meeting_frequency  \
# 0  Business/Productivity Software, Financial Soft...       [Bimonthly]
# 1  Fintech, vertical SaaS, Healthtech, Marketplac...         [Monthly]
# 2  (Global: AI, Bio + Healthcare, Consumer, Crypt...         [Monthly]
#
#   intros_made intros_received  \
# 0        14.0              16
# 1        13.0            13.0
# 2        14.0             3.0
#
#                                          description        domains  \
# 0  Bridge Partners is an early-stage investment f...  bridgelat.com
# 1  Latitud is the operating system for Latin Amer...    latitud.com
# 2  Andreessen Horowitz is a venture capital firm ...       a16z.com
#
#                                entry_id
# 0  007037bc-f043-424c-a9ef-0d7394eeed90
# 1  009e1d00-ddaa-4e35-8113-3b775dfe46c7
# 2  082a298f-a986-4686-becb-9905d63a806b
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Gdocs

# %%
# Importar bibliotecas necessárias para Google Docs
from googleapiclient.discovery import build
from google.oauth2 import service_account

# Configurar credenciais para Google Docs (usando as mesmas credenciais do Sheets)
SCOPES = ['https://www.googleapis.com/auth/documents.readonly']
creds = service_account.Credentials.from_service_account_file(
    '.secrets/service-account-admin.json',
    scopes=SCOPES
)

# Criar serviço do Google Docs
docs_service = build('docs', 'v1', credentials=creds)

# Função para obter conteúdo de um documento do Google Docs
def get_gdoc_content(doc_id):
    """
    Obtém o conteúdo de um documento do Google Docs pelo ID.
    
    Args:
        doc_id (str): ID do documento do Google Docs
        
    Returns:
        dict: Conteúdo do documento
    """
    try:
        # Fazer a requisição para obter o documento
        document = docs_service.documents().get(documentId=doc_id).execute()
        return document
    except Exception as e:
        print(f"Erro ao acessar o documento: {e}")
        return None


doc_ids = ["1WJDSO_uyTJ16DdkDOhgAUww4bMKuUa9fXuTh0HdkOew", "1F8jqD4pFq3_17NN75HZbzd2G2vrIqWaZqR1MOB5Fa6M", "182Qj0a8ZIXjS0_plWZdRY-aGY-X8qqpiIAUYex8xrd0"]
for doc_id in doc_ids:
    doc_content = get_gdoc_content(doc_id)
    if doc_content:
        print(f"Título do documento: {doc_content.get('title')}")
# Out:
# Título do documento: [AI MATERIAL] Definition of Lead and Follow
# Título do documento: [AI MATERIAL] Geographic Focus
# Título do documento: [AI MATERIAL] Preffered Industry

# %%
# Extrair texto do documento
doc_plaintext = ""
for item in doc_content.get('body').get('content'):
    if 'paragraph' in item:
        for element in item.get('paragraph').get('elements', []):
            if 'textRun' in element:
                doc_plaintext += element.get('textRun').get('content', '')

doc_plaintext
# Out:
# 'Analysis of Venture Capital Investment Preferences in Latin America\n1. Executive Summary\nThis report analyzes the preferred investment industries of a selected group of venture capital firms with a significant presence or interest in the Latin American market. The analysis reveals a strong concentration of investment in the technology sector, particularly within software-as-a-service (SaaS), financial technology (Fintech), and e-commerce enablers. While many firms exhibit a broad interest across various technology verticals, some demonstrate specialization in areas such as agritech, edtech, and climate technology. The findings highlight the dynamism and increasing maturity of the Latin American venture capital ecosystem, attracting both regional and global investors who are keen to capitalize on the region\'s burgeoning entrepreneurial landscape. Understanding these investment preferences is crucial for entrepreneurs seeking funding and for investors looking to identify key opportunities within this rapidly evolving market.\n2. Introduction: The Latin American Venture Capital Landscape\nThe venture capital ecosystem in Latin America has experienced significant growth and transformation in recent years, evolving from a nascent stage to a vibrant and increasingly attractive destination for global capital. The period around 2021 and 2022 marked a substantial inflection point, with investment volumes reaching unprecedented levels, dwarfing the cumulative investments of the preceding decade . This surge in activity underscores the growing recognition of the immense potential within the Latin American startup scene. However, it is crucial to acknowledge the inherent diversity of this landscape. What might prove successful in the Brazilian market, the largest in the region, may not necessarily translate to the unique dynamics of Mexico or the Spanish-speaking nations . Each country possesses its own distinct market characteristics, regulatory frameworks, and consumer behaviors, necessitating a nuanced understanding for effective investment strategies. This report delves into the investment preferences of several key venture capital firms active in Latin America, aiming to provide a comprehensive overview of the current trends and areas of focus within this dynamic ecosystem.  \n3. Investment Preferences of Key Venture Capital Firms in Latin America\n3.1. Bridge Latam\nEstablished in 2021 and headquartered in Mexico City, Bridge Latam operates as a venture capital investment firm with a clear focus on early-stage startups within the Latin American technology sector . The firm\'s emergence during a period of heightened venture capital activity in the region signifies the ongoing expansion of the investment landscape and the creation of new avenues for entrepreneurs seeking early funding. Bridge Latam\'s investment portfolio reveals a particular interest in sectors such as Business/Productivity Software, Financial Software, and Human Capital Services . This indicates a belief in the potential of technology to drive efficiency and innovation across various enterprise functions. Beyond its direct venture investments, Bridge Latam\'s involvement in market analysis, sourcing, and business development across Consumer Goods, Luxury Goods, and Capital Goods suggests a broader understanding of the Latin American market. This connection could imply a strategic approach to identifying and supporting technology solutions that can effectively address the needs and challenges within these more traditional industries. The firm\'s investment thesis centers on backing startups that demonstrate strong technological potential and the capacity for significant scalability, with a notable emphasis on the quality and vision of the founding team . With typical initial investments ranging from USD $200,000 to USD $500,000 , Bridge Latam positions itself as a key supporter of early-stage innovation in Latin America. In essence, Bridge Latam is an early-stage ...

# %% [markdown]
# ## AI

# %%
inputs = {
    "company": "Brendi",
    "description_company": "Brendi is a company that creates AI agents to sell food in Brazilian restaurants via delivery. They are going to be the next ifood",
    "description_person": "Daniel is the CEO of Brendi. he studied at ITA, is very young and energetic",
    "round": {"size": 10, "Funding": "Series A"},
    "round_commitment": "2M USD",
    "leader_or_follower": "leader",
    "industry": "AI Solutions, Food Delivery, Restaurant Management, AI Agents, Embedded Finance",
    "fund_closeness": "Close",
    "fund_quality": "High",
    "observations": "We are sure this deal is very hot, so we want the top funds with us in this one, but they have to fit the description of the company"
}

parameters = {
    "batch_size": 10,
    "surviving_percentage": 0.5,
}

# %%
BATCH_SIZE = 10
SURVIVING_PERCENTAGE = 0.5

# %%
if inputs["fund_closeness"] == "Close":
    proximity_weight = 2
elif inputs["fund_closeness"] == "Distant":
    proximity_weight = -2
else:
    proximity_weight = 0

if inputs["fund_quality"] == "High":
    fund_quality_weight = 2
elif inputs["fund_quality"] == "Medium":
    fund_quality_weight = 1
elif inputs["fund_quality"] == "Low":
    fund_quality_weight = -1
else:
    fund_quality_weight = 0

weights = {
    "proximity": proximity_weight,
    "investment_geography": 1,
    "fund_quality": fund_quality_weight,
    "round_compatibility": 1,
    "description_compatibility": 1,
}

# %%
# change empty strings to 0
df["vc_quality_perception"] = df["vc_quality_perception"].replace("", 0)
df["vc_quality_perception"] = df["vc_quality_perception"].astype(float, errors='ignore')
df["proximity"] = df["proximity"].replace("", 0)
df["proximity"] = df["proximity"].astype(float, errors='ignore')

# %%
possible_ranges = {
    "< USD 1mn": 1,
    "USD 5-10mn": 2,
    "USD 10-20mn": 3,
    "> USD 20mn": 4,
}

# check if funding round is inside what range
if inputs["round"]["size"] < 1:
    company_investment_range = "< USD 1mn"
elif inputs["round"]["size"] < 5:
    company_investment_range = ["USD 5-10mn", "< USD 1mn"]
elif inputs["round"]["size"] < 10:
    company_investment_range = ["USD 10-20mn", "USD 5-10mn", "< USD 1mn"]
else:
    company_investment_range = [">USD 20mn", "USD 10-20mn", "USD 5-10mn", "< USD 1mn"]

# remove from the df the rows that are not in the company_investment_range
# Converter a coluna investment_range de string para lista
# remove [ ]
df["investment_range"] = df["investment_range"].apply(lambda x: x.strip("[]"))

company_investment_range_pattern = '|'.join(company_investment_range)

# %%
### FILTERS ###
df = df[df["investment_range"].str.contains(company_investment_range_pattern, na=False)]

if inputs["leader_or_follower"] == "leader":
    # get only leader? that contains the word Leader (case insensitive)
    df = df[df["leader?"].str.lower().str.contains("leader")]
else:
    # get only follower? that contains the word Follower (case insensitive)
    df = df[df["leader?"].str.lower().str.contains("follower")]

if inputs["fund_quality"] == "High":
    df = df[df["vc_quality_perception"] >= 4]
elif inputs["fund_quality"] == "Medium":
    df = df[df["vc_quality_perception"] >= 3]

if inputs["fund_closeness"] == "Close":
    df = df[df["proximity"] >= 3]

# %%
df.columns
# Out:
# Index(['name', 'proximity', 'industry_agnostic', 'leader?',
#        'investment_geography', 'preferred_industry', 'vc_quality_perception',
#        'observations', 'investment_range', 'geo_origin',
#        'funding_rounds_1st_check', '', 'Opiniao Cache', 'investor_profile',
#        'prefered_industry_enriched', 'meeting_frequency', 'intros_made',
#        'intros_received', 'description', 'domains', 'entry_id'],
#       dtype='object')

# %%
cols_for_ai = ["name", "investment_geography", "prefered_industry_enriched", "description", "observations"]

# %%
from pydantic import BaseModel, Field
from typing import List

class FundScore(BaseModel):
    fund_name: str = Field(description="Fund Name")
    score: float = Field(description="Gross Score based on the sum of the criteria")
    reason: str = Field(description="Detailed reason for the score separated by criteria")

class FundScoreList(BaseModel):
    scores: List[FundScore]

def batch_splitter(df: pd.DataFrame) -> list[pd.DataFrame]:
    batch_size = BATCH_SIZE
    return [df[i:i+batch_size] for i in range(0, len(df), batch_size)]

def score_fund(state):
    system_prompt = """
    You are a fund score agent. Score every fund.
    You are given a table of funds, user inputs, and you need to score them based on the following criteria:

    - preffered_industry (the fund's preferred industry should be compatible with the company's industry. If there is just one intersection, the score is around 5. If there is a near perfect fit, the score is 10) | 0-10 points
    - investment_geography (the fund's investment geography should be compatible with the user's investment geography) | -5 to 5 points. If the geography is a perfect match, the score is 5. If the geography is not a perfect match, the score is 3. If incompatible, the score is -5
    - funding_rounds_1st_check (the first check round should be compatible with the round type) | 0-5 points
    - Description (the description should be compatible with the company's description) | 0-3 points
    - observations (Use it as a situational reference of the fund) | -5 to 5 points

    {previous_scores_guidance}
    """

    human_prompt = """
    Here is the table of funds:
    {df}

    Here is the user inputs:
    {inputs}
    """

    batches = batch_splitter(state["df"])
    
    # Inicializar lista para armazenar scores não normalizados
    if "raw_scores" not in state:
        state["raw_scores"] = []

    for i, batch in enumerate(batches):
        # Preparar orientação baseada em pontuações anteriores
        previous_scores_guidance = ""
        if state["raw_scores"]:
            # Criar exemplos de pontuações anteriores para manter consistência
            examples = [(s.fund_name, s.score) for s in state["raw_scores"][:5]]
            previous_scores_guidance = f""" 
            IMPORTANT: Keep consistency with the scores already assigned to other funds.
            Examples of previous scores: {examples}
            Remember that the total score must be in an approximate scale with the scores already assigned.
            """
        
        prompt = ChatPromptTemplate.from_messages([
            ("system", system_prompt.format(previous_scores_guidance=previous_scores_guidance)),
            ("human", human_prompt)
        ])

        structured_llm = claude_3_7_bedrock.with_structured_output(FundScoreList)
        chain = prompt | structured_llm

        # Converter batch para string
        batch_str = batch.to_string()
        
        # Invocar o modelo
        fund_scores = chain.invoke({"df": batch_str, "inputs": inputs})
        
        # Guardar pontuações brutas
        state["raw_scores"].extend(fund_scores.scores)
        
        print(f"Processado lote {i+1}/{len(batches)}")

    # Normalizar todas as pontuações no final
    if state["raw_scores"]:
        min_score = min(score.score for score in state["raw_scores"])
        max_score = max(score.score for score in state["raw_scores"])
        
        if max_score > min_score:  # evitar divisão por zero
            state["fund_scores"] = [
                FundScore(
                    fund_name=score.fund_name,
                    score=100 * (score.score - min_score) / (max_score - min_score),
                    reason=score.reason
                ) for score in state["raw_scores"]
            ]
        else:
            # Caso todas as pontuações sejam iguais
            state["fund_scores"] = [
                FundScore(
                    fund_name=score.fund_name,
                    score=50.0,  # valor médio arbitrário
                    reason=score.reason
                ) for score in state["raw_scores"]
            ]

    return state

initial_state = {
    "df":df[cols_for_ai],
    "fund_scores":[],
    "raw_scores":[]
}

result = score_fund(initial_state)
# Out:
# Processado lote 1/2
# Processado lote 2/2

# %%
sorted_results = sorted(result["fund_scores"], key=lambda x: x.score, reverse=True)
sorted_results
# Out:
# [FundScore(fund_name='Monashees', score=100.0, reason="Investment range: 4/5 - As a leading LatAm investor, they can lead a $2M investment in a $10M Series A. Geography: 5/5 - LatAm focus matches perfectly with Brendi's Brazilian market. Funding rounds: 4/5 - They invest in various stages and support scaling businesses. Description: 3/3 - Their investment in marketplaces, consumption and technology solutions directly aligns with Brendi's AI food delivery platform. Observations: 3/5 - Identified as a top-tier fund which meets the requirement for quality investors in this hot deal."),
#  FundScore(fund_name='Kaszek', score=94.11764705882354, reason="Investment range: 4/5 - As a top-tier LatAm fund, they can likely lead a $2M investment in a $10M round. Geography: 5/5 - LatAm-focused fund perfectly matches Brendi's Brazilian market. Funding rounds: 4/5 - They support high-impact technology companies at various stages including Series A. Description: 3/3 - They invest in a wide range of technology including marketplaces which would include Brendi's food delivery platform. Observations: 2/5 - Noted as a top-tier fund which aligns with the requirement for top funds in this hot deal."),
#  FundScore(fund_name='Valor Capital Group', score=94.11764705882354, reason="Investment range: 4/5 - As a global top-tier fund, they likely have capacity to lead a $10M Series A with a $2M commitment, though they could potentially commit more. Investment geography: 5/5 - Perfect match with Brazil focus and US-Brazil cross-border opportunities. Funding rounds: 4/5 - Well positioned for Series A investments. Description compatibility: 3/3 - Their expertise in technology markets and interest in transformative businesses aligns perfectly with Brendi's AI platform disrupting food delivery. Observations: 2/5 - Their top-tier status and specific interest in Web3/Crypto isn't directly related to Brendi's AI food delivery, but their overall quality matches the requirement for a high-quality fund."),
#  FundScore(fund_name='Atlantico', score=88.23529411764706, reason="Investment range: 4/5 - Their focus on Series A rounds suggests they can lead a $10M round with a $2M commitment, though ideally a leader would commit more. Investment geography: 5/5 - Perfect match with Latam/Brazil focus. Funding rounds: 5/5 - Specifically targets Series A companies with product-market fit. Description compatibility: 3/3 - Their diverse tech portfolio and interest in high-growth industries aligns perfectly with Brendi's AI-powered food delivery platform. Observations: 0/5 - Their agnostic approach works well for Brendi but doesn't provide any special industry expertise in food tech or delivery."),
#  FundScore(fund_name='big_bets', score=82.3529411764706, reason="Investment range: 4/5 - They partner from Day 1 and could provide the $2M lead in a $10M Series A. Geography: 5/5 - Brazil is their primary focus which matches Brendi perfectly. Funding rounds: 4/5 - They fund companies from early stages and support their growth. Description: 3/3 - They invest in AI and Software which aligns well with Brendi's AI agents. Observations: 0/5 - Strong Brazil focus makes them relevant, but no specific observations about their leading capabilities in this size."),
#  FundScore(fund_name='Astella', score=76.47058823529412, reason="Investment range: 3/5 - As a Brazilian VC focused on early-stage, they could lead a Series A but the $2M commitment for a $10M round is slightly below ideal for a leader. Investment geography: 5/5 - Perfect match with Brazil focus. Funding rounds: 4/5 - Well-suited for Series A investments in their core markets. Description compatibility: 3/3 - Their focus on innovative marketplaces, data-driven solutions and AI aligns perfectly with Brendi's AI-powered food delivery platform. Observations: 0/5 - Their GTM strategy specialization could be valuable but isn't specifically aligned with the food delivery or AI agent space."),
#  FundScore(fund_name='Alexia Ventures', score=70.58823529411765, reason="Investment range: 3/5 - Early-stage investor but check size not specified, likely can do $2M. Geography: 5/5 - LatAm focused, perfect for Brazilian company. Funding rounds: 3/5 - Early-stage focus which could include Series A. Description: 3/3 - Software, AI and data focus aligns perfectly with Brendi's AI agents for restaurants. Observations: 0/5 - Their SaaS and AI businesses focus matches well with Brendi's offering."),
#  FundScore(fund_name='Upload', score=70.58823529411765, reason="Investment range: 3/5 - Their across-all-stages approach means they could lead a Series A, but the $2M commitment is somewhat low for a $10M round leader. Investment geography: 4/5 - Global focus that includes Brazil is a good match, though not exclusive to Latam. Funding rounds: 4/5 - Their all-stages approach includes Series A. Description compatibility: 3/3 - Strong alignment with their focus on AI and scalable B2B software, perfectly matching Brendi's AI agent technology. Observations: 0/5 - Their agnostic approach works well, but doesn't provide any specific advantage for the food delivery or restaurant tech space."),
#  FundScore(fund_name='MAYA Capital', score=64.70588235294117, reason="Investment range: 3/5 - Early-stage focus but no specific check size mentioned. Geography: 5/5 - LatAm-focused matches Brendi's Brazilian market perfectly. Funding rounds: 2/5 - Early-stage focus may include Series A but not explicitly mentioned. Description: 3/3 - They invest in marketplaces, e-commerce and tech that supports digital transformation, which aligns with Brendi's mission. Observations: 0/5 - Their solo player status and increasing closeness could make them interested in this hot deal."),
#  FundScore(fund_name='Canary', score=64.70588235294117, reason="Investment range: 2/5 - Their focus on early-stage investments isn't ideal for leading a Series A with a $2M commitment when the round size is $10M (leader should commit at least $5M). Investment geography: 5/5 - Perfect match with Latam/Brazil focus. Funding rounds: 3/5 - They primarily focus on earlier stages but do participate in Series A. Description compatibility: 3/3 - Strong alignment with tech investments including marketplaces which aligns well with Brendi's AI-powered food delivery platform. Observations: 0/5 - While they're a solid fund, their 'pre-op businesses' focus doesn't fully align with a Series A company that's already operating."),
#  FundScore(fund_name='NXTP Ventures', score=58.8235294117647, reason="Investment range: 2/5 - They invest $500k to $3M which could technically lead but might be at their upper limit. Geography: 5/5 - LatAm focused fund perfectly matches Brendi's Brazilian market. Funding rounds: 3/5 - They're early stage but can lead rounds in this range. Description: 2/3 - They invest in AI and data-driven businesses which aligns with Brendi's AI agents. Observations: 0/5 - They're B2B focused which partially fits, but Brendi has a consumer-facing component."),
#  FundScore(fund_name='ONEVC', score=52.94117647058823, reason="Investment range: 2/5 - Seed stage specialist may not be positioned to lead a $2M investment in Series A. Geography: 5/5 - LatAm focus matches Brendi perfectly. Funding rounds: 1/5 - They focus on seed stage, which is earlier than Brendi's Series A. Description: 3/3 - While not explicitly mentioning AI, they invest in category-defining tech companies which could include Brendi. Observations: 0/5 - Noted as rising top-tier fund and solo players, could be interested but Series A might be later than their sweet spot."),
#  FundScore(fund_name='Andreessen Horowitz', score=47.05882352941177, reason="Investment range: 2/5 - While they focus on Series A+, their investment range is likely larger than needed for a $2M lead in a $10M round. Geography: 3/5 - They invest globally including LatAm. Funding rounds: 3/5 - They do Series A which matches the round. Description: 2/3 - They invest in AI and consumer tech which aligns with Brendi's AI agents for food delivery. Observations: 0/5 - They typically require larger check sizes for leading rounds."),
#  FundScore(fund_name='Quona Capital', score=41.1764705882353, reason="Investment range: 2/5 - Not specified, but as a global investor they likely can do $2M investments. Geography: 4/5 - Global with emerging markets focus includes Brazil. Funding rounds: 2/5 - No specific stage focus mentioned. Description: 1/3 - They focus on fintech inclusion which only partially aligns with Brendi's embedded finance aspect. Observations: 0/5 - Their fintech focus doesn't strongly align with Brendi's primary AI food delivery business."),
#  FundScore(fund_name='Across Capital Partners', score=0.0, reason="Investment range: 0/5 - They focus on companies with >$5M ARR which is likely beyond Brendi's current stage. Geography: 3/5 - Global with US focus but does include LatAm. Funding rounds: 0/5 - They appear to focus on later-stage companies. Description: 1/3 - They invest in technology but more financial software focused. Observations: -2/5 - Their requirement for >$5M ARR with 50%+ growth suggests they're not aligned with Brendi's stage.")]

# %%
import math
to_keep = parameters["surviving_percentage"]*len(result["fund_scores"])
to_keep = math.ceil(to_keep)
to_keep
# Out:
# 8

# %%
kept_funds = sorted_results[:to_keep]
kept_funds
# Out:
# [FundScore(fund_name='Monashees', score=100.0, reason="Investment range: 4/5 - As a leading LatAm investor, they can lead a $2M investment in a $10M Series A. Geography: 5/5 - LatAm focus matches perfectly with Brendi's Brazilian market. Funding rounds: 4/5 - They invest in various stages and support scaling businesses. Description: 3/3 - Their investment in marketplaces, consumption and technology solutions directly aligns with Brendi's AI food delivery platform. Observations: 3/5 - Identified as a top-tier fund which meets the requirement for quality investors in this hot deal."),
#  FundScore(fund_name='Kaszek', score=94.11764705882354, reason="Investment range: 4/5 - As a top-tier LatAm fund, they can likely lead a $2M investment in a $10M round. Geography: 5/5 - LatAm-focused fund perfectly matches Brendi's Brazilian market. Funding rounds: 4/5 - They support high-impact technology companies at various stages including Series A. Description: 3/3 - They invest in a wide range of technology including marketplaces which would include Brendi's food delivery platform. Observations: 2/5 - Noted as a top-tier fund which aligns with the requirement for top funds in this hot deal."),
#  FundScore(fund_name='Valor Capital Group', score=94.11764705882354, reason="Investment range: 4/5 - As a global top-tier fund, they likely have capacity to lead a $10M Series A with a $2M commitment, though they could potentially commit more. Investment geography: 5/5 - Perfect match with Brazil focus and US-Brazil cross-border opportunities. Funding rounds: 4/5 - Well positioned for Series A investments. Description compatibility: 3/3 - Their expertise in technology markets and interest in transformative businesses aligns perfectly with Brendi's AI platform disrupting food delivery. Observations: 2/5 - Their top-tier status and specific interest in Web3/Crypto isn't directly related to Brendi's AI food delivery, but their overall quality matches the requirement for a high-quality fund."),
#  FundScore(fund_name='Atlantico', score=88.23529411764706, reason="Investment range: 4/5 - Their focus on Series A rounds suggests they can lead a $10M round with a $2M commitment, though ideally a leader would commit more. Investment geography: 5/5 - Perfect match with Latam/Brazil focus. Funding rounds: 5/5 - Specifically targets Series A companies with product-market fit. Description compatibility: 3/3 - Their diverse tech portfolio and interest in high-growth industries aligns perfectly with Brendi's AI-powered food delivery platform. Observations: 0/5 - Their agnostic approach works well for Brendi but doesn't provide any special industry expertise in food tech or delivery."),
#  FundScore(fund_name='big_bets', score=82.3529411764706, reason="Investment range: 4/5 - They partner from Day 1 and could provide the $2M lead in a $10M Series A. Geography: 5/5 - Brazil is their primary focus which matches Brendi perfectly. Funding rounds: 4/5 - They fund companies from early stages and support their growth. Description: 3/3 - They invest in AI and Software which aligns well with Brendi's AI agents. Observations: 0/5 - Strong Brazil focus makes them relevant, but no specific observations about their leading capabilities in this size."),
#  FundScore(fund_name='Astella', score=76.47058823529412, reason="Investment range: 3/5 - As a Brazilian VC focused on early-stage, they could lead a Series A but the $2M commitment for a $10M round is slightly below ideal for a leader. Investment geography: 5/5 - Perfect match with Brazil focus. Funding rounds: 4/5 - Well-suited for Series A investments in their core markets. Description compatibility: 3/3 - Their focus on innovative marketplaces, data-driven solutions and AI aligns perfectly with Brendi's AI-powered food delivery platform. Observations: 0/5 - Their GTM strategy specialization could be valuable but isn't specifically aligned with the food delivery or AI agent space."),
#  FundScore(fund_name='Alexia Ventures', score=70.58823529411765, reason="Investment range: 3/5 - Early-stage investor but check size not specified, likely can do $2M. Geography: 5/5 - LatAm focused, perfect for Brazilian company. Funding rounds: 3/5 - Early-stage focus which could include Series A. Description: 3/3 - Software, AI and data focus aligns perfectly with Brendi's AI agents for restaurants. Observations: 0/5 - Their SaaS and AI businesses focus matches well with Brendi's offering."),
#  FundScore(fund_name='Upload', score=70.58823529411765, reason="Investment range: 3/5 - Their across-all-stages approach means they could lead a Series A, but the $2M commitment is somewhat low for a $10M round leader. Investment geography: 4/5 - Global focus that includes Brazil is a good match, though not exclusive to Latam. Funding rounds: 4/5 - Their all-stages approach includes Series A. Description compatibility: 3/3 - Strong alignment with their focus on AI and scalable B2B software, perfectly matching Brendi's AI agent technology. Observations: 0/5 - Their agnostic approach works well, but doesn't provide any specific advantage for the food delivery or restaurant tech space.")]

# %%
doc_plaintext
# Out:
# 'Analysis of Venture Capital Investment Preferences in Latin America\n1. Executive Summary\nThis report analyzes the preferred investment industries of a selected group of venture capital firms with a significant presence or interest in the Latin American market. The analysis reveals a strong concentration of investment in the technology sector, particularly within software-as-a-service (SaaS), financial technology (Fintech), and e-commerce enablers. While many firms exhibit a broad interest across various technology verticals, some demonstrate specialization in areas such as agritech, edtech, and climate technology. The findings highlight the dynamism and increasing maturity of the Latin American venture capital ecosystem, attracting both regional and global investors who are keen to capitalize on the region\'s burgeoning entrepreneurial landscape. Understanding these investment preferences is crucial for entrepreneurs seeking funding and for investors looking to identify key opportunities within this rapidly evolving market.\n2. Introduction: The Latin American Venture Capital Landscape\nThe venture capital ecosystem in Latin America has experienced significant growth and transformation in recent years, evolving from a nascent stage to a vibrant and increasingly attractive destination for global capital. The period around 2021 and 2022 marked a substantial inflection point, with investment volumes reaching unprecedented levels, dwarfing the cumulative investments of the preceding decade . This surge in activity underscores the growing recognition of the immense potential within the Latin American startup scene. However, it is crucial to acknowledge the inherent diversity of this landscape. What might prove successful in the Brazilian market, the largest in the region, may not necessarily translate to the unique dynamics of Mexico or the Spanish-speaking nations . Each country possesses its own distinct market characteristics, regulatory frameworks, and consumer behaviors, necessitating a nuanced understanding for effective investment strategies. This report delves into the investment preferences of several key venture capital firms active in Latin America, aiming to provide a comprehensive overview of the current trends and areas of focus within this dynamic ecosystem.  \n3. Investment Preferences of Key Venture Capital Firms in Latin America\n3.1. Bridge Latam\nEstablished in 2021 and headquartered in Mexico City, Bridge Latam operates as a venture capital investment firm with a clear focus on early-stage startups within the Latin American technology sector . The firm\'s emergence during a period of heightened venture capital activity in the region signifies the ongoing expansion of the investment landscape and the creation of new avenues for entrepreneurs seeking early funding. Bridge Latam\'s investment portfolio reveals a particular interest in sectors such as Business/Productivity Software, Financial Software, and Human Capital Services . This indicates a belief in the potential of technology to drive efficiency and innovation across various enterprise functions. Beyond its direct venture investments, Bridge Latam\'s involvement in market analysis, sourcing, and business development across Consumer Goods, Luxury Goods, and Capital Goods suggests a broader understanding of the Latin American market. This connection could imply a strategic approach to identifying and supporting technology solutions that can effectively address the needs and challenges within these more traditional industries. The firm\'s investment thesis centers on backing startups that demonstrate strong technological potential and the capacity for significant scalability, with a notable emphasis on the quality and vision of the founding team . With typical initial investments ranging from USD $200,000 to USD $500,000 , Bridge Latam positions itself as a key supporter of early-stage innovation in Latin America. In essence, Bridge Latam is an early-stage ...

# %%
fund_names = []
for fund in kept_funds:
    fund_names.append(fund.fund_name)
fund_names
# Out:
# ['Monashees',
#  'Kaszek',
#  'Valor Capital Group',
#  'Atlantico',
#  'big_bets',
#  'Astella',
#  'Alexia Ventures',
#  'Upload']

# %%
df_first_filter = df[df["name"].isin(fund_names)]
df_first_filter.head(2)
# Out:
#                   name                                      Opiniao Pedro  \
# 2  Andreessen Horowitz  Lots of money, hyped, low activity in Brazil. ...
# 3             big_bets  Pure software, they don't like hardware. Rarel...
#
#   Opiniao Gus industry_agnostic              leader? investment_geography  \
# 2                          TRUE  Leader and Follower               Global
# 3                                Leader and Follower          Brazil, USA
#
#   preferred_industry vc_quality_perception                observations  \
# 2                 []                   5.0  Focusing more on Series A+
# 3                 []                   4.0    Brazil and Global thesis
#
#                                    investment_range  ...   Opiniao Cache  \
# 2  [USD 1-5mn, USD 5-10mn, USD 10-20mn, > USD 20mn]  ...
# 3                            [< USD 1mn, USD 1-5mn]  ...
#
#   investor_profile                         prefered_industry_enriched  \
# 2               VC  (Global: AI, Bio + Healthcare, Consumer, Crypt...
# 3               VC  Software (IDtech, AI, SaaS, Fintech, Edtech, G...
#
#   meeting_frequency intros_made intros_received  \
# 2         [Monthly]        14.0             3.0
# 3         [Monthly]        18.0            44.0
#
#                                          description         domains  \
# 2  Andreessen Horowitz is a venture capital firm ...        a16z.com
# 3  big_bets is a venture capital and private equi...  bigbets.com.br
#
#                                entry_id
# 2  082a298f-a986-4686-becb-9905d63a806b
# 3  0920744a-6cdf-4992-9ecd-f370cb240be6
#
# [2 rows x 22 columns]
